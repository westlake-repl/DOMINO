# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/sujin/PycharmProjects/Pretraining")

# %%
path = "/sujin/Datasets/TED/FusionPDB/fusion_gene_pair_proteins.tsv"
with open(path, "r") as r:
    next(r)
    for line in r:
        fusion_id, _, _, seq_1, seq_2 = line.strip().split("\t")
        # print(seq_1, seq_2)
        # break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1553/1534892938.py in <cell line: 2>()
#       3     next(r)
#       4     for line in r:
# ----> 5         fusion_id, _, _, seq_1, seq_2 = line.strip().split("\t")
#       6         # print(seq_1, seq_2)
#       7         # break
#
# ValueError: not enough values to unpack (expected 5, got 4)
